# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python -m spacy download en_core_web_lg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-lg==3.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.3.0/en_core_web_lg-3.3.0-py3-none-any.whl (400.7 MB)
#      |████████████████████████████████| 400.7 MB 6.4 kB/s
# Requirement already satisfied: spacy<3.4.0,>=3.3.0.dev0 in /usr/local/lib/python3.7/dist-packages (from en-core-web-lg==3.3.0) (3.3.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (4.64.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (0.9.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (3.0.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (57.4.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (8.0.17)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (2.23.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (2.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (1.21.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (2.0.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (2.11.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (3.3.0)
# Requirement already satisfied: typing-extensions<4.2.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (4.1.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (0.7.7)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (2.4.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (1.0.7)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (1.0.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (0.4.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (1.8.2)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (0.6.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (21.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (5.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (1.24.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.4.0,>=3.3.0.dev0->en-core-web-lg==3.3.0) (2.0.1)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.3.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
import en_core_web_lg
import pandas as pd
import re
import random
import spacy
from spacy.util import minibatch, compounding
import warnings
import matplotlib.pyplot as plt

# %%
food_df = pd.read_csv("/content/drive/MyDrive/job work/food.csv")
food_df.head()
# Out:
#     fdc_id          data_type  \
# 0  1105904       branded_food
# 1  1105905       branded_food
# 2  1105906       branded_food
# 3  1105907       branded_food
# 4  1105898  experimental_food
#
#                                          description  food_category_id  \
# 0                         WESSON Vegetable Oil 1 GAL               NaN
# 1                                 SWANSON BROTH BEEF               NaN
# 2           CAMPBELL'S SLOW KETTLE SOUP CLAM CHOWDER               NaN
# 3        CAMPBELL'S SLOW KETTLE SOUP CHEESE BROCCOLI               NaN
# 4  Discrepancy between the Atwater factor predict...               NaN
#
#   publication_date
# 0       2020-11-13
# 1       2020-11-13
# 2       2020-11-13
# 3       2020-11-13
# 4       2020-10-30

# %%
food_df["description"].size
# Out:
# 1687318

# %%
foods = food_df[food_df["description"].str.contains("[^a-zA-Z ]") == False]["description"].apply(lambda food: food.lower())

# %%
foods = foods[foods.str.split().apply(len) <= 3].drop_duplicates()

# %%
foods.size
# Out:
# 41634

# %%
foods
# Out:
# 1               swanson broth beef
# 9            swanson broth chicken
# 31         pepperidge farm cookies
# 41           pepperidge farm bread
# 48         swanson broth vegetable
#                     ...
# 1678853               honey liquor
# 1678854            blackberry beer
# 1678976                  pignolias
# 1679000          spooky rope candy
# 1679012        edible zombie slime
# Name: description, Length: 41634, dtype: object

# %%
one_worded_foods = foods[foods.str.split().apply(len) == 1]
two_worded_foods = foods[foods.str.split().apply(len) == 2]
three_worded_foods = foods[foods.str.split().apply(len) == 3]

# %%
one_worded_foods.size
# Out:
# 1453

# %%
two_worded_foods.size
# Out:
# 14022

# %%
three_worded_foods.size
# Out:
# 26159

# %%
foods = one_worded_foods.append(two_worded_foods[:1000])

# %%
foods = foods.append(three_worded_foods[:1000])

# %%
food_templates = [
    "I ate my {}",
    "I'm eating a {}",
    "I just ate a {}",
    "I only ate the {}",
    "I'm done eating a {}",
    "I've already eaten a {}",
    "I just finished my {}",
    "When I was having lunch I ate a {}",
    "I had a {} and a {} today",
    "I ate a {} and a {} for lunch",
    "I made a {} and {} for lunch",
    "I ate {} and {}",
    "today I ate a {} and a {} for lunch",
    "I had {} with my husband last night",
    "I brought you some {} on my birthday",
    "I made {} for yesterday's dinner",
    "last night, a {} was sent to me with {}",
    "I had {} yesterday and I'd like to eat it anyway",
    "I ate a couple of {} last night",
    "I had some {} at dinner last night",
    "Last night, I ordered some {}",
    "I made a {} last night",
    "I had a bowl of {} with {} and I wanted to go to the mall today",
    "I brought a basket of {} for breakfast this morning",
    "I had a bowl of {}",
    "I ate a {} with {} in the morning",
    "I made a bowl of {} for my breakfast",
    "There's {} for breakfast in the bowl this morning",
    "This morning, I made a bowl of {}",
    "I decided to have some {} as a little bonus",
    "I decided to enjoy some {}",
    "I've decided to have some {} for dessert",
    "I had a {}, a {} and {} at home",
    "I took a {}, {} and {} on the weekend",
    "I ate a {} with {} and {} just now",
    "Last night, I ate an {} with {} and {}",
    "I tasted some {}, {} and {} at the office",
    "There's a basket of {}, {} and {} that I consumed",
    "I devoured a {}, {} and {}",
    "I've already had a bag of {}, {} and {} from the fridge"
]

# %%
TRAIN_FOOD_DATA = {
    "one_food": [],
    "two_foods": [],
    "three_foods": []
}

TEST_FOOD_DATA = {
    "one_food": [],
    "two_foods": [],
    "three_foods": []
}

FOOD_SENTENCE_LIMIT = 167

def get_food_data(count):
    return {
        1: TRAIN_FOOD_DATA["one_food"] if len(TRAIN_FOOD_DATA["one_food"]) < FOOD_SENTENCE_LIMIT else TEST_FOOD_DATA["one_food"],
        2: TRAIN_FOOD_DATA["two_foods"] if len(TRAIN_FOOD_DATA["two_foods"]) < FOOD_SENTENCE_LIMIT else TEST_FOOD_DATA["two_foods"],
        3: TRAIN_FOOD_DATA["three_foods"] if len(TRAIN_FOOD_DATA["three_foods"]) < FOOD_SENTENCE_LIMIT else TEST_FOOD_DATA["three_foods"],
    }[count]

pattern_to_replace = "{}"

foods = foods.sample(frac=1)

food_entity_count = foods.size - 1

while food_entity_count >= 2:
    entities = []

    sentence = food_templates[random.randint(0, len(food_templates) - 1)]

    matches = re.findall(pattern_to_replace, sentence)

    for match in matches:
        food = foods.iloc[food_entity_count]
        food_entity_count -= 1

        sentence = sentence.replace(match, food, 1)
        match_span = re.search(food, sentence).span()

        entities.append((match_span[0], match_span[1], "FOOD"))

    get_food_data(len(matches)).append((sentence, {"entities": entities}))

# %%
TRAIN_FOOD_DATA
# Out:
# {'one_food': [('I had french baguette with my husband last night',
#    {'entities': [(6, 21, 'FOOD')]}),
#   ('This morning, I made a bowl of waffle fries',
#    {'entities': [(31, 43, 'FOOD')]}),
#   ('I brought you some chunky crushed tomatoes on my birthday',
#    {'entities': [(19, 42, 'FOOD')]}),
#   ("I'm done eating a uncured ham", {'entities': [(18, 29, 'FOOD')]}),
#   ('I had broccoli cuts with my husband last night',
#    {'entities': [(6, 19, 'FOOD')]}),
#   ('I just ate a premium mangos', {'entities': [(13, 27, 'FOOD')]}),
#   ('I ate my caponata', {'entities': [(9, 17, 'FOOD')]}),
#   ("I made kosher dill pickles for yesterday's dinner",
#    {'entities': [(7, 26, 'FOOD')]}),
#   ('I only ate the passion flower', {'entities': [(15, 29, 'FOOD')]}),
#   ("There's reddiegg for breakfast in the bowl this morning",
#    {'entities': [(8, 16, 'FOOD')]}),
#   ("I made smoky bbq sauce for yesterday's dinner",
#    {'entities': [(7, 22, 'FOOD')]}),
#   ("There's puffins for breakfast in the bowl this morning",
#    {'entities': [(8, 15, 'FOOD')]}),
#   ('I only ate the cola', {'entities': [(15, 19, 'FOOD')]}),
#   ('I ate my artichoke hearts', {'entities': [(9, 25, 'FOOD')]}),
#   ('This morning, I made a bowl of tequesquite',
#    {'entities': [(31, 42, 'FOOD')]}),
#   ('I just finished my parmesan chicken', {'entities': [(19, 35, 'FOOD')]}),
#   ("I've already eaten a limburger", {'entities': [(21, 30, 'FOOD')]}),
#   ("There's shells for breakfast in the bowl this morning",
#    {'entities': [(8, 14, 'FOOD')]}),
#   ("I'm done eating a snowflake roll", {'entities': [(18, 32, 'FOOD')]}),
#   ("I've decided to have some salted corn for dessert",
#    {'entities': [(26, 37, 'FOOD')]}),
#   ('I decided to have some ground turkey breast as a little bonus',
#    {'entities': [(23, 43, 'FOOD')]}),
#   ('I had some cooked shrimp at dinner last night',
#    {'entities': [(11, 24, 'FOOD')]}),
#   ('I just finished my rustica', {'entities': [(19, 26, 'FOOD')]}),
#   ('I just finished my fall harvest salad', {'entities': [(19, 37, 'FOOD')]}),
#   ('I made a peppered salame last night', {'entities': [(9, 24, 'FOOD')]}),
#   ("I had jelly beans yesterday and I'd like to eat it anyway",
#    {'entities': [(6, 17, 'FOOD')]}),
#   ('Last night, I ordered some dry whole milk',
#    {'entities': [(27, 41, 'FOOD')]}),
#   ('Last night, I ordered some sour lovers candies',
#    {'entities': [(27, 46, 'FOOD')]}),
#   ("I've already eaten a margherita", {'entities': [(21, 31, 'FOOD')]}),
#   ("I made mimosa for yesterday's dinner", {'entities': [(7, 13, 'FOOD')]}),
#   ('I made a hot italian sausage last night', {'entities': [(9, 28, 'FOOD')]}),
#   ("I had avocado oil yesterday and I'd like to eat it anyway",
#    {'entities': [(6, 17, 'FOOD')]}),
#   ('I made a bowl of nocciolata for my breakfast',
#    {'entities': [(17, 27, 'FOOD')]}),
#   ("I made pecan pie for yesterday's dinner", {'entities': [(7, 16, 'FOOD')]}),
#   ('I made a bowl of favereds for my breakfast',
#    {'entities': [(17, 25, 'FOOD')]}),
#   ('This morning, I made a bowl of enriched bread',
#    {'entities': [(31, 45, 'FOOD')]}),
#   ('I had a bowl of moussaka', {'entities': [(16, 24, 'FOOD')]}),
#   ('This morning, I made a bowl of hashbrowns',
#    {'entities': [(31, 41, 'FOOD')]}),
#   ('When I was having lunch I ate a sugar crystals',
#    {'entities': [(32, 46, 'FOOD')]}),
#   ("There's holiday trees candy for breakfast in the bowl this morning",
#    {'entities': [(8, 27, 'FOOD')]}),
#   ('I ate a couple of skyr last night', {'entities': [(18, 22, 'FOOD')]}),
#   ('This morning, I made a bowl of almond raisin granola',
#    {'entities': [(31, 52, 'FOOD')]}),
#   ('I ate a couple of scalloped potatoes last night',
#    {'entities': [(18, 36, 'FOOD')]}),
#   ('I ate my steamable broccoli cuts', {'entities': [(9, 32, 'FOOD')]}),
#   ('I made a bowl of brownie for my breakfast',
#    {'entities': [(17, 24, 'FOOD')]}),
#   ("I've decided to have some talancina for dessert",
#    {'entities': [(26, 35, 'FOOD')]}),
#   ('I ate my fajita seasoning', {'entities': [(9, 25, 'FOOD')]}),
#   ("I've decided to have some blue sharks for dessert",
#    {'entities': [(26, 37, 'FOOD')]}),
#   ("I've already eaten a mesquite rub", {'entities': [(21, 33, 'FOOD')]}),
#   ('Last night, I ordered some christmas jelly wreaths',
#    {'entities': [(27, 50, 'FOOD')]}),
#   ('I had snowtop juju with my husband last night',
#    {'entities': [(6, 18, 'FOOD')]}),
#   ('This morning, I made a bowl of taziki', {'entities': [(31, 37, 'FOOD')]}),
#   ("I made organic petite peas for yesterday's dinner",
#    {'entities': [(7, 26, 'FOOD')]}),
#   ('I had some conscons at dinner last night',
#    {'entities': [(11, 19, 'FOOD')]}),
#   ('This morning, I made a bowl of cashew pieces',
#    {'entities': [(31, 44, 'FOOD')]}),
#   ('When I was having lunch I ate a burrito',
#    {'entities': [(32, 39, 'FOOD')]}),
#   ('I decided to have some jumbo franks as a little bonus',
#    {'entities': [(23, 35, 'FOOD')]}),
#   ("I've already eaten a orecchiette", {'entities': [(21, 32, 'FOOD')]}),
#   ('I decided to enjoy some caramels', {'entities': [(24, 32, 'FOOD')]}),
#   ('I brought you some cakes on my birthday',
#    {'entities': [(19, 24, 'FOOD')]}),
#   ('I brought a basket of icey for breakfast this morning',
#    {'entities': [(22, 26, 'FOOD')]}),
#   ('I decided to have some royale as a little bonus',
#    {'entities': [(23, 29, 'FOOD')]}),
#   ('I only ate the greyhound', {'entities': [(15, 24, 'FOOD')]}),
#   ('I had a bowl of delishaved', {'entities': [(16, 26, 'FOOD')]}),
#   ("I had garlic yesterday and I'd like to eat it anyway",
#    {'entities': [(6, 12, 'FOOD')]}),
#   ('I made a bowl of sliced braunschweiger liverwurst for my breakfast',
#    {'entities': [(17, 49, 'FOOD')]}),
#   ('I brought you some macadamias on my birthday',
#    {'entities': [(19, 29, 'FOOD')]}),
#   ("I had panela yesterday and I'd like to eat it anyway",
#    {'entities': [(6, 12, 'FOOD')]}),
#   ("I had sliced brioche loaf yesterday and I'd like to eat it anyway",
#    {'entities': [(6, 25, 'FOOD')]}),
#   ('Last night, I ordered some red cooking wine',
#    {'entities': [(27, 43, 'FOOD')]}),
#   ("I'm eating a eggplant", {'entities': [(13, 21, 'FOOD')]}),
#   ('I made a bowl of telera for my breakfast',
#    {'entities': [(17, 23, 'FOOD')]}),
#   ("I'm eating a vegetable", {'entities': [(13, 22, 'FOOD')]}),
#   ('I decided to have some vegetable base as a little bonus',
#    {'entities': [(23, 37, 'FOOD')]}),
#   ('When I was having lunch I ate a hulled hemp seed',
#    {'entities': [(32, 48, 'FOOD')]}),
#   ('I ate a couple of milk chocolate last night',
#    {'entities': [(18, 32, 'FOOD')]}),
#   ("There's multigrain for breakfast in the bowl this morning",
#    {'entities': [(8, 18, 'FOOD')]}),
#   ("I had cayennade yesterday and I'd like to eat it anyway",
#    {'entities': [(6, 15, 'FOOD')]}),
#   ('I brought a basket of gems for breakfast this morning',
#    {'entities': [(22, 26, 'FOOD')]}),
#   ("I've decided to have some vegan fish fillet for dessert",
#    {'entities': [(26, 43, 'FOOD')]}),
#   ('This morning, I made a bowl of roasted peanut oil',
#    {'entities': [(31, 49, 'FOOD')]}),
#   ('I brought you some frittatas on my birthday',
#    {'entities': [(19, 28, 'FOOD')]}),
#   ("I've already eaten a wheat crackers", {'entities': [(21, 35, 'FOOD')]}),
#   ("I'm eating a blue sharks candy", {'entities': [(13, 30, 'FOOD')]}),
#   ('When I was having lunch I ate a basics black beans',
#    {'entities': [(32, 50, 'FOOD')]}),
#   ('I brought a basket of cane sugar for breakfast this morning',
#    {'entities': [(22, 32, 'FOOD')]}),
#   ('I just ate a topping', {'entities': [(13, 20, 'FOOD')]}),
#   ("I had hash yesterday and I'd like to eat it anyway",
#    {'entities': [(6, 10, 'FOOD')]}),
#   ('I had some egg angel hair at dinner last night',
#    {'entities': [(11, 25, 'FOOD')]}),
#   ('I made a salami last night', {'entities': [(9, 15, 'FOOD')]}),
#   ("I'm eating a heart cookies", {'entities': [(13, 26, 'FOOD')]}),
#   ('When I was having lunch I ate a ale', {'entities': [(32, 35, 'FOOD')]}),
#   ('When I was having lunch I ate a butterfly',
#    {'entities': [(32, 41, 'FOOD')]}),
#   ('I made a bowl of twin demi baguette for my breakfast',
#    {'entities': [(17, 35, 'FOOD')]}),
#   ('I made a tortiglioni last night', {'entities': [(9, 20, 'FOOD')]}),
#   ("I'm done eating a pruuns", {'entities': [(18, 24, 'FOOD')]}),
#   ('I made a neon squiggles last night', {'entities': [(9, 23, 'FOOD')]}),
#   ('I decided to enjoy some pork ham steamship',
#    {'entities': [(24, 42, 'FOOD')]}),
#   ('I made a bowl of hamburgers for my breakfast',
#    {'entities': [(17, 27, 'FOOD')]}),
#   ('I just finished my prosciutto americano',
#    {'entities': [(19, 39, 'FOOD')]}),
#   ('I decided to have some egg substitute as a little bonus',
#    {'entities': [(23, 37, 'FOOD')]}),
#   ('I ate my bartlett pears', {'entities': [(9, 23, 'FOOD')]}),
#   ('I only ate the stixx carrot', {'entities': [(15, 27, 'FOOD')]}),
#   ('I had a bowl of chia milled seeds', {'entities': [(16, 33, 'FOOD')]}),
#   ('I just finished my dill pickle', {'entities': [(19, 30, 'FOOD')]}),
#   ('I ate a couple of organic sweet peas last night',
#    {'entities': [(18, 36, 'FOOD')]}),
#   ('I decided to have some fancy snow peas as a little bonus',
#    {'entities': [(23, 38, 'FOOD')]}),
#   ('I made a iodized salt last night', {'entities': [(9, 21, 'FOOD')]}),
#   ("I've decided to have some ramen for dessert",
#    {'entities': [(26, 31, 'FOOD')]}),
#   ("I've already eaten a sandwich cookies", {'entities': [(21, 37, 'FOOD')]}),
#   ("I had chopped kale yesterday and I'd like to eat it anyway",
#    {'entities': [(6, 18, 'FOOD')]}),
#   ("I've decided to have some saxonshires for dessert",
#    {'entities': [(26, 37, 'FOOD')]}),
#   ("I made srirachanaise for yesterday's dinner",
#    {'entities': [(7, 20, 'FOOD')]}),
#   ('I brought you some spicy seaweed sprinkle on my birthday',
#    {'entities': [(19, 41, 'FOOD')]}),
#   ('I only ate the sour cream', {'entities': [(15, 25, 'FOOD')]}),
#   ("I'm done eating a gum", {'entities': [(18, 21, 'FOOD')]}),
#   ('I made a spinach last night', {'entities': [(9, 16, 'FOOD')]}),
#   ('I decided to enjoy some green split peas',
#    {'entities': [(24, 40, 'FOOD')]}),
#   ('I just ate a orange candy shred', {'entities': [(13, 31, 'FOOD')]}),
#   ("I'm done eating a italian bread", {'entities': [(18, 31, 'FOOD')]}),
#   ("I made panquecitos for yesterday's dinner",
#    {'entities': [(7, 18, 'FOOD')]}),
#   ("I'm eating a churritos", {'entities': [(13, 22, 'FOOD')]}),
#   ("There's florentines for breakfast in the bowl this morning",
#    {'entities': [(8, 19, 'FOOD')]}),
#   ('I brought a basket of cupcake decorating kit for breakfast this morning',
#    {'entities': [(22, 44, 'FOOD')]}),
#   ("I'm done eating a gourmet jelly beans", {'entities': [(18, 37, 'FOOD')]}),
#   ('I ate a couple of limon last night', {'entities': [(18, 23, 'FOOD')]}),
#   ('This morning, I made a bowl of brioche', {'entities': [(31, 38, 'FOOD')]}),
#   ("I'm eating a mangos", {'entities': [(13, 19, 'FOOD')]}),
#   ('I had some pork tocino at dinner last night',
#    {'entities': [(11, 22, 'FOOD')]}),
#   ('I decided to have some shredded potato patties as a little bonus',
#    {'entities': [(23, 46, 'FOOD')]}),
#   ("There's frutesca for breakfast in the bowl this morning",
#    {'entities': [(8, 16, 'FOOD')]}),
#   ("I've already eaten a sugar", {'entities': [(21, 26, 'FOOD')]}),
#   ('I decided to have some frankfurters as a little bonus',
#    {'entities': [(23, 35, 'FOOD')]}),
#   ("I've decided to have some puding for dessert",
#    {'entities': [(26, 32, 'FOOD')]}),
#   ("There's elbows for breakfast in the bowl this morning",
#    {'entities': [(8, 14, 'FOOD')]}),
#   ('Last night, I ordered some holiday non pareils',
#    {'entities': [(27, 46, 'FOOD')]}),
#   ('I ate a couple of glazed donut sticks last night',
#    {'entities': [(18, 37, 'FOOD')]}),
#   ('I made a bowl of pure okara flour for my breakfast',
#    {'entities': [(17, 33, 'FOOD')]}),
#   ('I brought you some natural spring water on my birthday',
#    {'entities': [(19, 39, 'FOOD')]}),
#   ('Last night, I ordered some baklava', {'entities': [(27, 34, 'FOOD')]}),
#   ('I just ate a sprinkle', {'entities': [(13, 21, 'FOOD')]}),
#   ('I brought you some mushroom on my birthday',
#    {'entities': [(19, 27, 'FOOD')]}),
#   ('This morning, I made a bowl of mini drinks',
#    {'entities': [(31, 42, 'FOOD')]}),
#   ('When I was having lunch I ate a moussecake',
#    {'entities': [(32, 42, 'FOOD')]}),
#   ('I ate a couple of original last night', {'entities': [(18, 26, 'FOOD')]}),
#   ('I decided to enjoy some graham', {'entities': [(24, 30, 'FOOD')]}),
#   ("I've decided to have some pez candy for dessert",
#    {'entities': [(26, 35, 'FOOD')]}),
#   ('I decided to enjoy some fig', {'entities': [(24, 27, 'FOOD')]}),
#   ('I had some pizza sauce at dinner last night',
#    {'entities': [(11, 22, 'FOOD')]}),
#   ("I've already eaten a cracker", {'entities': [(21, 28, 'FOOD')]}),
#   ("There's dijonnaise for breakfast in the bowl this morning",
#    {'entities': [(8, 18, 'FOOD')]}),
#   ('When I was having lunch I ate a coconut milk',
#    {'entities': [(32, 44, 'FOOD')]}),
#   ("There's fancy maraschino cherries for breakfast in the bowl this morning",
#    {'entities': [(8, 33, 'FOOD')]}),
#   ('I brought a basket of celery salt for breakfast this morning',
#    {'entities': [(22, 33, 'FOOD')]}),
#   ('I had a bowl of fine pink salt', {'entities': [(16, 30, 'FOOD')]}),
#   ('I ate my petite peas', {'entities': [(9, 20, 'FOOD')]}),
#   ("I'm eating a beer cheese", {'entities': [(13, 24, 'FOOD')]}),
#   ('I had raisin with my husband last night', {'entities': [(6, 12, 'FOOD')]}),
#   ('I decided to enjoy some flapjack', {'entities': [(24, 32, 'FOOD')]}),
#   ('Last night, I ordered some chili mix', {'entities': [(27, 36, 'FOOD')]}),
#   ('Last night, I ordered some chocolate flavored toffee',
#    {'entities': [(27, 52, 'FOOD')]}),
#   ('Last night, I ordered some shrimp scampi',
#    {'entities': [(27, 40, 'FOOD')]}),
#   ('I just finished my gummy sharks', {'entities': [(19, 31, 'FOOD')]}),
#   ('I decided to enjoy some buttermilk', {'entities': [(24, 34, 'FOOD')]}),
#   ('Last night, I ordered some diabetic', {'entities': [(27, 35, 'FOOD')]}),
#   ('I just ate a energy drink', {'entities': [(13, 25, 'FOOD')]}),
#   ('I had real mayonnaise with my husband last night',
#    {'entities': [(6, 21, 'FOOD')]})],
#  'three_foods': [('I had a tuna salad, a cassava and chewy candy at home',
#    {'entities': [(8, 18, 'FOOD'), (22, 29, 'FOOD'), (34, 45, 'FOOD')]}),
#   ('I took a crystal ginger, premium bbq buns and scones on the weekend',
#    {'entities': [(9, 23, 'FOOD'), (25, 41, 'FOOD'), (46, 52, 'FOOD')]}),
#   ('I tasted some condiment, mango and frankfurts at the office',
#    {'entities': [(14, 23, 'FOOD'), (25, 30, 'FOOD'), (35, 45, 'FOOD')]}),
#   ('I took a bolillo rolls, mangoes and pumpkin pie on the weekend',
#    {'entities': [(9, 22, 'FOOD'), (24, 31, 'FOOD'), (36, 47, 'FOOD')]}),
#   ('I had a claw crabmeat, a simply bananas and broccoli beef sauce at home',
#    {'entities': [(8, 21, 'FOOD'), (25, 39, 'FOOD'), (44, 63, 'FOOD')]}),
#   ('I devoured a fondant, chanterelles and muffuletta',
#    {'entities': [(13, 20, 'FOOD'), (22, 34, 'FOOD'), (39, 49, 'FOOD')]}),
#   ('I tasted some valencia oranges, papad and pink salt flakes at the office',
#    {'entities': [(14, 30, 'FOOD'), (32, 37, 'FOOD'), (42, 58, 'FOOD')]}),
#   ('Last night, I ate an clam bisque with cones and cinnamon',
#    {'entities': [(21, 32, 'FOOD'), (38, 43, 'FOOD'), (48, 56, 'FOOD')]}),
#   ('I had a beets, a colored sugars and souvlaki at home',
#    {'entities': [(8, 13, 'FOOD'), (17, 31, 'FOOD'), (36, 44, 'FOOD')]}),
#   ("I've already had a bag of rice, salmon and soup from the fridge",
#    {'entities': [(26, 30, 'FOOD'), (32, 38, 'FOOD'), (43, 47, 'FOOD')]}),
#   ("There's a basket of pitted kalamata olives, mini candy canes and italian blend that I consumed",
#    {'entities': [(20, 42, 'FOOD'), (44, 60, 'FOOD'), (65, 78, 'FOOD')]}),
#   ("I've already had a bag of ghee, mint meltaways and braunschweiger from the fridge",
#    {'entities': [(26, 30, 'FOOD'), (32, 46, 'FOOD'), (51, 65, 'FOOD')]}),
#   ('I had a whole raspberries, a mango slices and mini brownies blondie at home',
#    {'entities': [(8, 25, 'FOOD'), (29, 41, 'FOOD'), (46, 67, 'FOOD')]}),
#   ('I had a whipping cream, a crunchy squash chips and star fruit salad at home',
#    {'entities': [(8, 22, 'FOOD'), (26, 46, 'FOOD'), (51, 67, 'FOOD')]}),
#   ('I devoured a dark salt caramel, dill relish and kettle baked pops',
#    {'entities': [(13, 30, 'FOOD'), (32, 43, 'FOOD'), (48, 65, 'FOOD')]}),
#   ('I devoured a pickles, loaf and jumbo topping cherries',
#    {'entities': [(13, 20, 'FOOD'), (22, 26, 'FOOD'), (31, 53, 'FOOD')]}),
#   ('I took a habanero, diced medley mushrooms and hickory smoked bacon on the weekend',
#    {'entities': [(9, 17, 'FOOD'), (19, 41, 'FOOD'), (46, 66, 'FOOD')]}),
#   ('I devoured a toastables, maraschino and jalapenos',
#    {'entities': [(13, 23, 'FOOD'), (25, 35, 'FOOD'), (40, 49, 'FOOD')]}),
#   ('I ate a nonfat cottage cheese with zaban and fusillo just now',
#    {'entities': [(8, 29, 'FOOD'), (35, 40, 'FOOD'), (45, 52, 'FOOD')]}),
#   ('I took a garlic dill pickles, cheese delicato tortelloni and golbar on the weekend',
#    {'entities': [(9, 28, 'FOOD'), (30, 56, 'FOOD'), (61, 67, 'FOOD')]}),
#   ('I devoured a blackberry, gumdrops and sprinkle mix',
#    {'entities': [(13, 23, 'FOOD'), (25, 33, 'FOOD'), (38, 50, 'FOOD')]}),
#   ('Last night, I ate an seltzerwater with tomato and curry',
#    {'entities': [(21, 33, 'FOOD'), (39, 45, 'FOOD'), (50, 55, 'FOOD')]}),
#   ("I've already had a bag of french dressing, crunchers and sliced almonds from the fridge",
#    {'entities': [(26, 41, 'FOOD'), (43, 52, 'FOOD'), (57, 71, 'FOOD')]}),
#   ("I've already had a bag of icing decorations, fine sea salt and shelled pecans from the fridge",
#    {'entities': [(26, 43, 'FOOD'), (45, 58, 'FOOD'), (63, 77, 'FOOD')]}),
#   ("There's a basket of tropical mix, mojo criollo and plain catfish nuggets that I consumed",
#    {'entities': [(20, 32, 'FOOD'), (34, 46, 'FOOD'), (51, 72, 'FOOD')]}),
#   ('I ate a whole flax seeds with whole rotisserie chicken and glazed yeast rings just now',
#    {'entities': [(8, 24, 'FOOD'), (30, 54, 'FOOD'), (59, 77, 'FOOD')]}),
#   ("There's a basket of deluxe navy beans, ditalini and vegan pad thai that I consumed",
#    {'entities': [(20, 37, 'FOOD'), (39, 47, 'FOOD'), (52, 66, 'FOOD')]}),
#   ("There's a basket of sour lovers, drinks and gluten free rotini that I consumed",
#    {'entities': [(20, 31, 'FOOD'), (33, 39, 'FOOD'), (44, 62, 'FOOD')]}),
#   ('I devoured a cut asparagus spears, chocolate almonds and cream of coconut',
#    {'entities': [(13, 33, 'FOOD'), (35, 52, 'FOOD'), (57, 73, 'FOOD')]}),
#   ('I ate a sakar with gruyere shredded cheese and olives salad just now',
#    {'entities': [(8, 13, 'FOOD'), (19, 42, 'FOOD'), (47, 59, 'FOOD')]}),
#   ('I ate a caserecci with brookie and organic mangos just now',
#    {'entities': [(8, 17, 'FOOD'), (23, 30, 'FOOD'), (35, 49, 'FOOD')]}),
#   ('Last night, I ate an pear ginger preserbes with singles and cocktail juice drink',
#    {'entities': [(21, 42, 'FOOD'), (48, 55, 'FOOD'), (60, 80, 'FOOD')]}),
#   ('I devoured a johnnycake, martini and cigar',
#    {'entities': [(13, 23, 'FOOD'), (25, 32, 'FOOD'), (37, 42, 'FOOD')]}),
#   ('Last night, I ate an squeezers with assorted chocolate and bouillon',
#    {'entities': [(21, 30, 'FOOD'), (36, 54, 'FOOD'), (59, 67, 'FOOD')]}),
#   ("There's a basket of baked lentil chips, minced garlic and allsorts that I consumed",
#    {'entities': [(20, 38, 'FOOD'), (40, 53, 'FOOD'), (58, 66, 'FOOD')]}),
#   ('I devoured a cheeseburger, peppermints and pesto',
#    {'entities': [(13, 25, 'FOOD'), (27, 38, 'FOOD'), (43, 48, 'FOOD')]}),
#   ('Last night, I ate an white vegan kimchi with ice cream and hunkola',
#    {'entities': [(21, 39, 'FOOD'), (45, 54, 'FOOD'), (59, 66, 'FOOD')]}),
#   ("I've already had a bag of premium ultimate apricots, scrapple and honey mustered dressing from the fridge",
#    {'entities': [(26, 51, 'FOOD'), (53, 61, 'FOOD'), (66, 89, 'FOOD')]}),
#   ('I tasted some milk, cookies  and hot banana peppers at the office',
#    {'entities': [(14, 18, 'FOOD'), (20, 28, 'FOOD'), (33, 51, 'FOOD')]}),
#   ('I tasted some potato chiips, beignet and pink salmon at the office',
#    {'entities': [(14, 27, 'FOOD'), (29, 36, 'FOOD'), (41, 52, 'FOOD')]}),
#   ('I took a giardiniera, fresh vegan mozz and sourdougb on the weekend',
#    {'entities': [(9, 20, 'FOOD'), (22, 38, 'FOOD'), (43, 52, 'FOOD')]}),
#   ("There's a basket of morsels, pop candy and toffee that I consumed",
#    {'entities': [(20, 27, 'FOOD'), (29, 38, 'FOOD'), (43, 49, 'FOOD')]}),
#   ('I took a carmelita, tortelloni chicken mozzarella and sundae on the weekend',
#    {'entities': [(9, 18, 'FOOD'), (20, 49, 'FOOD'), (54, 60, 'FOOD')]}),
#   ('Last night, I ate an crescents with arborio rice and dum',
#    {'entities': [(21, 30, 'FOOD'), (36, 48, 'FOOD'), (53, 56, 'FOOD')]}),
#   ('I devoured a diced green peppers, donut and marshmallow pop',
#    {'entities': [(13, 32, 'FOOD'), (34, 39, 'FOOD'), (44, 59, 'FOOD')]}),
#   ('Last night, I ate an udon with german potato salad and infused pesto oil',
#    {'entities': [(21, 25, 'FOOD'), (31, 50, 'FOOD'), (55, 72, 'FOOD')]}),
#   ('Last night, I ate an parboiled with ravioli and sorbet',
#    {'entities': [(21, 30, 'FOOD'), (36, 43, 'FOOD'), (48, 54, 'FOOD')]}),
#   ('I devoured a margarita, assorted cookies and big chewy candy',
#    {'entities': [(13, 22, 'FOOD'), (24, 40, 'FOOD'), (45, 60, 'FOOD')]}),
#   ('Last night, I ate an pasteurized cream cheese with strong dark chocolate and creme brulee',
#    {'entities': [(21, 45, 'FOOD'), (51, 72, 'FOOD'), (77, 89, 'FOOD')]}),
#   ('Last night, I ate an pine nuts with fudgesicle and chocolatey',
#    {'entities': [(21, 30, 'FOOD'), (36, 46, 'FOOD'), (51, 61, 'FOOD')]}),
#   ('I tasted some tortilleria, green peppers and baby koshers at the office',
#    {'entities': [(14, 25, 'FOOD'), (27, 40, 'FOOD'), (45, 57, 'FOOD')]}),
#   ('I had a whole pine nuts, a menudo and mixed vegetables at home',
#    {'entities': [(8, 23, 'FOOD'), (27, 33, 'FOOD'), (38, 54, 'FOOD')]}),
#   ("There's a basket of cupkakes, lychee and sliced pickled beets that I consumed",
#    {'entities': [(20, 28, 'FOOD'), (30, 36, 'FOOD'), (41, 61, 'FOOD')]}),
#   ('I took a tintern, guava paste and supertea on the weekend',
#    {'entities': [(9, 16, 'FOOD'), (18, 29, 'FOOD'), (34, 42, 'FOOD')]}),
#   ('I tasted some scallops, aceto balsamico and cultured sour cream at the office',
#    {'entities': [(14, 22, 'FOOD'), (24, 39, 'FOOD'), (44, 63, 'FOOD')]}),
#   ("I've already had a bag of hush puppies, kolkas and dried vegetables from the fridge",
#    {'entities': [(26, 38, 'FOOD'), (40, 46, 'FOOD'), (51, 67, 'FOOD')]}),
#   ('I tasted some dolmas, pecan pieces and premium organic strawberries at the office',
#    {'entities': [(14, 20, 'FOOD'), (22, 34, 'FOOD'), (39, 67, 'FOOD')]}),
#   ('Last night, I ate an matzos with vegetarian vegetable soup and gazpacho',
#    {'entities': [(21, 27, 'FOOD'), (33, 58, 'FOOD'), (63, 71, 'FOOD')]}),
#   ('I had a sesame dipping sauce, a popcron and chopped pecans at home',
#    {'entities': [(8, 28, 'FOOD'), (32, 39, 'FOOD'), (44, 58, 'FOOD')]}),
#   ('I had a apple juice, a honey and pepperoni at home',
#    {'entities': [(8, 19, 'FOOD'), (23, 28, 'FOOD'), (33, 42, 'FOOD')]}),
#   ("I've already had a bag of arbol chile pods, sunflower kernels and roasted salted peanuts from the fridge",
#    {'entities': [(26, 42, 'FOOD'), (44, 61, 'FOOD'), (66, 88, 'FOOD')]}),
#   ("There's a basket of pizzaboli, ornament cookies and onion buns that I consumed",
#    {'entities': [(20, 29, 'FOOD'), (31, 47, 'FOOD'), (52, 62, 'FOOD')]}),
#   ("There's a basket of black walnuts, carmarsh and turkey snack sticks that I consumed",
#    {'entities': [(20, 33, 'FOOD'), (35, 43, 'FOOD'), (48, 67, 'FOOD')]}),
#   ("There's a basket of pumpkin solid packed, wild blueberries and maria cookies that I consumed",
#    {'entities': [(20, 40, 'FOOD'), (42, 58, 'FOOD'), (63, 76, 'FOOD')]}),
#   ('Last night, I ate an kosher dills with mix and english walnuts',
#    {'entities': [(21, 33, 'FOOD'), (39, 42, 'FOOD'), (47, 62, 'FOOD')]}),
#   ("I've already had a bag of double protein oats, soft licorice and krimpies from the fridge",
#    {'entities': [(26, 45, 'FOOD'), (47, 60, 'FOOD'), (65, 73, 'FOOD')]}),
#   ('I ate a decorated cookie with whole kalamata olives and gourmet wildcat sauce just now',
#    {'entities': [(8, 24, 'FOOD'), (30, 51, 'FOOD'), (56, 77, 'FOOD')]}),
#   ("I've already had a bag of toasted pita bits, uncured genoa salami and sardines from the fridge",
#    {'entities': [(26, 43, 'FOOD'), (45, 65, 'FOOD'), (70, 78, 'FOOD')]}),
#   ('I tasted some limes, nutty honey granola and milk duds at the office',
#    {'entities': [(14, 19, 'FOOD'), (21, 40, 'FOOD'), (45, 54, 'FOOD')]}),
#   ("There's a basket of pizza seasoning, coconut water and plant based patties that I consumed",
#    {'entities': [(20, 35, 'FOOD'), (37, 50, 'FOOD'), (55, 74, 'FOOD')]}),
#   ('I took a mezzelune, chipotle sauce and bacon on the weekend',
#    {'entities': [(9, 18, 'FOOD'), (20, 34, 'FOOD'), (39, 44, 'FOOD')]}),
#   ("There's a basket of macaroni, baked cheese puffs and gyro puff that I consumed",
#    {'entities': [(20, 28, 'FOOD'), (30, 48, 'FOOD'), (53, 62, 'FOOD')]}),
#   ('I ate a marigate with iced brownie bites and teriyaki veggie burger just now',
#    {'entities': [(8, 16, 'FOOD'), (22, 40, 'FOOD'), (45, 67, 'FOOD')]}),
#   ('Last night, I ate an pesto oil with holiday pretzels shapes and diced new potatoes',
#    {'entities': [(21, 30, 'FOOD'), (36, 59, 'FOOD'), (64, 82, 'FOOD')]}),
#   ("There's a basket of creamers, snackpies and cucharitas that I consumed",
#    {'entities': [(20, 28, 'FOOD'), (30, 39, 'FOOD'), (44, 54, 'FOOD')]}),
#   ('Last night, I ate an heavy whipping cream with black juju bears and gari',
#    {'entities': [(21, 41, 'FOOD'), (47, 63, 'FOOD'), (68, 72, 'FOOD')]}),
#   ('I tasted some ripple potato chips, whole carrots and hard salami at the office',
#    {'entities': [(14, 33, 'FOOD'), (35, 48, 'FOOD'), (53, 64, 'FOOD')]}),
#   ('I ate a spears with woodfired garlic rub and browning just now',
#    {'entities': [(8, 14, 'FOOD'), (20, 40, 'FOOD'), (45, 53, 'FOOD')]}),
#   ('I tasted some cardamom, gherkins and candy jewelry at the office',
#    {'entities': [(14, 22, 'FOOD'), (24, 32, 'FOOD'), (37, 50, 'FOOD')]}),
#   ('I devoured a rye, organic carrots and meal',
#    {'entities': [(13, 16, 'FOOD'), (18, 33, 'FOOD'), (38, 42, 'FOOD')]}),
#   ('I had a dessert, a purified drinking water and mint at home',
#    {'entities': [(8, 15, 'FOOD'), (19, 42, 'FOOD'), (47, 51, 'FOOD')]}),
#   ("I've already had a bag of nectars, panini and runts from the fridge",
#    {'entities': [(26, 33, 'FOOD'), (35, 41, 'FOOD'), (46, 51, 'FOOD')]}),
#   ('I ate a organic hamburger buns with molasses cookies and toffee peanuts just now',
#    {'entities': [(8, 30, 'FOOD'), (36, 52, 'FOOD'), (57, 71, 'FOOD')]}),
#   ('I ate a semolina with alfredo and full flavor molasses just now',
#    {'entities': [(8, 16, 'FOOD'), (22, 29, 'FOOD'), (34, 54, 'FOOD')]}),
#   ('Last night, I ate an cornsticks with beef franks and corn muffins',
#    {'entities': [(21, 31, 'FOOD'), (37, 48, 'FOOD'), (53, 65, 'FOOD')]}),
#   ('I took a tumbler with gumballs, raw agave nectar and sliced apples on the weekend',
#    {'entities': [(9, 30, 'FOOD'), (32, 48, 'FOOD'), (53, 66, 'FOOD')]}),
#   ("There's a basket of uncured hot pepperoni, zucchini sticks and couscous that I consumed",
#    {'entities': [(20, 41, 'FOOD'), (43, 58, 'FOOD'), (63, 71, 'FOOD')]}),
#   ('I ate a distiued white vinegar with baked vegetable crisps and marinara sauce just now',
#    {'entities': [(8, 30, 'FOOD'), (36, 58, 'FOOD'), (63, 77, 'FOOD')]}),
#   ('Last night, I ate an rods pretzels with orange zest chicken and plain',
#    {'entities': [(21, 34, 'FOOD'), (40, 59, 'FOOD'), (64, 69, 'FOOD')]}),
#   ("I've already had a bag of sliced brioche, teriyaki sauce and russet potatoes from the fridge",
#    {'entities': [(26, 40, 'FOOD'), (42, 56, 'FOOD'), (61, 76, 'FOOD')]}),
#   ('I ate a coconut flour with sweetener packets and center cut bacon just now',
#    {'entities': [(8, 21, 'FOOD'), (27, 44, 'FOOD'), (49, 65, 'FOOD')]}),
#   ("I've already had a bag of milk chocolates hearts, tasty bean sprout and estrellitas from the fridge",
#    {'entities': [(26, 48, 'FOOD'), (50, 67, 'FOOD'), (72, 83, 'FOOD')]}),
#   ('I took a whole flaxseed, cream soda and kalamata olives on the weekend',
#    {'entities': [(9, 23, 'FOOD'), (25, 35, 'FOOD'), (40, 55, 'FOOD')]}),
#   ('I tasted some harbison, soft tofu and ground flax seeds at the office',
#    {'entities': [(14, 22, 'FOOD'), (24, 33, 'FOOD'), (38, 55, 'FOOD')]}),
#   ('I had a yogurt peanuts, a tabouli and chopped spinach at home',
#    {'entities': [(8, 22, 'FOOD'), (26, 33, 'FOOD'), (38, 53, 'FOOD')]}),
#   ('I devoured a banger, organic edamame spaghetti and steamable broccoli florets',
#    {'entities': [(13, 19, 'FOOD'), (21, 46, 'FOOD'), (51, 77, 'FOOD')]}),
#   ("I've already had a bag of minis cookies, cut green beans and white arborio rice from the fridge",
#    {'entities': [(26, 39, 'FOOD'), (41, 56, 'FOOD'), (61, 79, 'FOOD')]}),
#   ('I took a peperoncini, smoked gouda and spin pop on the weekend',
#    {'entities': [(9, 20, 'FOOD'), (22, 34, 'FOOD'), (39, 47, 'FOOD')]}),
#   ('I tasted some pinto beans, snap peas and cornstarch at the office',
#    {'entities': [(14, 25, 'FOOD'), (27, 36, 'FOOD'), (41, 51, 'FOOD')]}),
#   ('I devoured a paste, hominy and romaine',
#    {'entities': [(13, 18, 'FOOD'), (20, 26, 'FOOD'), (31, 38, 'FOOD')]}),
#   ('I tasted some chicken pot pie, breakfast bacon wrap and caserecce at the office',
#    {'entities': [(14, 29, 'FOOD'), (31, 51, 'FOOD'), (56, 65, 'FOOD')]}),
#   ('I ate a water with harvard beets and steak seasoning just now',
#    {'entities': [(8, 13, 'FOOD'), (19, 32, 'FOOD'), (37, 52, 'FOOD')]}),
#   ('I ate a tuscan with okara and succotash just now',
#    {'entities': [(8, 14, 'FOOD'), (20, 25, 'FOOD'), (30, 39, 'FOOD')]}),
#   ('Last night, I ate an peppercorn blend with stir fry mix and base',
#    {'entities': [(21, 37, 'FOOD'), (43, 55, 'FOOD'), (60, 64, 'FOOD')]}),
#   ('I devoured a giardinera, regular pie shells and caramels ',
#    {'entities': [(13, 23, 'FOOD'), (25, 43, 'FOOD'), (48, 57, 'FOOD')]}),
#   ('I devoured a tikka masala sauce, curd and sliced spanish olives',
#    {'entities': [(13, 31, 'FOOD'), (33, 37, 'FOOD'), (42, 63, 'FOOD')]}),
#   ('I took a kiwifruit, plant powered patties and cauliflower rice pilaf on the weekend',
#    {'entities': [(9, 18, 'FOOD'), (20, 41, 'FOOD'), (46, 68, 'FOOD')]}),
#   ("There's a basket of superdrink, lowfat milk and meat that I consumed",
#    {'entities': [(20, 30, 'FOOD'), (32, 43, 'FOOD'), (48, 52, 'FOOD')]}),
#   ("There's a basket of browines, blt pasta salad and mixed pickling spice that I consumed",
#    {'entities': [(20, 28, 'FOOD'), (30, 45, 'FOOD'), (50, 70, 'FOOD')]}),
#   ('I tasted some croutons, organic peanut butter and coarse sea salt at the office',
#    {'entities': [(14, 22, 'FOOD'), (24, 45, 'FOOD'), (50, 65, 'FOOD')]}),
#   ("I've already had a bag of prunes, applesauce and textured vegetable protein from the fridge",
#    {'entities': [(26, 32, 'FOOD'), (34, 44, 'FOOD'), (49, 75, 'FOOD')]}),
#   ('I tasted some wafer, animal cookies and gorditas at the office',
#    {'entities': [(14, 19, 'FOOD'), (21, 35, 'FOOD'), (40, 48, 'FOOD')]}),
#   ('Last night, I ate an garbanzo beans with garlic powder and hulled millet',
#    {'entities': [(21, 35, 'FOOD'), (41, 54, 'FOOD'), (59, 72, 'FOOD')]}),
#   ("There's a basket of organic blueberries, soymilk and raisin cake that I consumed",
#    {'entities': [(20, 39, 'FOOD'), (41, 48, 'FOOD'), (53, 64, 'FOOD')]}),
#   ('Last night, I ate an cheese tortellini pasta with blackberries and shelled brazils',
#    {'entities': [(21, 44, 'FOOD'), (50, 62, 'FOOD'), (67, 82, 'FOOD')]}),
#   ("I've already had a bag of naked alaskan salmon, whole raw almonds and sandwiches from the fridge",
#    {'entities': [(26, 46, 'FOOD'), (48, 65, 'FOOD'), (70, 80, 'FOOD')]}),
#   ("There's a basket of brat buns, orange juice and celebration cake that I consumed",
#    {'entities': [(20, 29, 'FOOD'), (31, 43, 'FOOD'), (48, 64, 'FOOD')]}),
#   ('I tasted some stock, butterfinger and hummous at the office',
#    {'entities': [(14, 19, 'FOOD'), (21, 33, 'FOOD'), (38, 45, 'FOOD')]}),
#   ('I took a organic mixed vegetables, chopped garlic and milk chocolates on the weekend',
#    {'entities': [(9, 33, 'FOOD'), (35, 49, 'FOOD'), (54, 69, 'FOOD')]}),
#   ('I ate a crispy sauerkraut with crispbread and sugarfree energy drink just now',
#    {'entities': [(8, 25, 'FOOD'), (31, 41, 'FOOD'), (46, 68, 'FOOD')]}),
#   ('I devoured a soybeans, vegetable dumplings and cherry',
#    {'entities': [(13, 21, 'FOOD'), (23, 42, 'FOOD'), (47, 53, 'FOOD')]}),
#   ('I took a mini, crumbled goat cheese and avocado on the weekend',
#    {'entities': [(9, 13, 'FOOD'), (15, 35, 'FOOD'), (40, 47, 'FOOD')]}),
#   ('I had a sopes, a buffalo and sourdough at home',
#    {'entities': [(8, 13, 'FOOD'), (17, 24, 'FOOD'), (29, 38, 'FOOD')]}),
#   ('Last night, I ate an cut broccoli with sliced raclette cheese and quartered artichoke hearts',
#    {'entities': [(21, 33, 'FOOD'), (39, 61, 'FOOD'), (66, 92, 'FOOD')]}),
#   ("There's a basket of organic riced cauliflower, pink candy shred and fruity that I consumed",
#    {'entities': [(20, 45, 'FOOD'), (47, 63, 'FOOD'), (68, 74, 'FOOD')]}),
#   ("There's a basket of mussels, brazil nuts and cilantro that I consumed",
#    {'entities': [(20, 27, 'FOOD'), (29, 40, 'FOOD'), (45, 53, 'FOOD')]}),
#   ("I've already had a bag of authentic guacamole, clementeenies and organic berry medley from the fridge",
#    {'entities': [(26, 45, 'FOOD'), (47, 60, 'FOOD'), (65, 85, 'FOOD')]}),
#   ('I devoured a easy leaves petites, decorating and breadcrumbs',
#    {'entities': [(13, 32, 'FOOD'), (34, 44, 'FOOD'), (49, 60, 'FOOD')]}),
#   ('I devoured a plums, mirepoix and refreshers',
#    {'entities': [(13, 18, 'FOOD'), (20, 28, 'FOOD'), (33, 43, 'FOOD')]}),
#   ('Last night, I ate an gummy blue sharks with cobbler and guacamole singles',
#    {'entities': [(21, 38, 'FOOD'), (44, 51, 'FOOD'), (56, 73, 'FOOD')]}),
#   ('I had a concord confections, a crackerz and tortelloni at home',
#    {'entities': [(8, 27, 'FOOD'), (31, 39, 'FOOD'), (44, 54, 'FOOD')]}),
#   ('I devoured a bacon goetta, rellenitas and crispy battered rockfish',
#    {'entities': [(13, 25, 'FOOD'), (27, 37, 'FOOD'), (42, 66, 'FOOD')]}),
#   ('I ate a broccoli rabe with candy cane and swanson broth vegetable just now',
#    {'entities': [(8, 21, 'FOOD'), (27, 37, 'FOOD'), (42, 65, 'FOOD')]}),
#   ('I tasted some spring nonpareils, whole strawberries and bunny at the office',
#    {'entities': [(14, 31, 'FOOD'), (33, 51, 'FOOD'), (56, 61, 'FOOD')]}),
#   ('I ate a japanese chile pods with bockwurst and zesty just now',
#    {'entities': [(8, 27, 'FOOD'), (33, 42, 'FOOD'), (47, 52, 'FOOD')]}),
#   ('I devoured a meatloaf, slammer bun and pork ham boneless',
#    {'entities': [(13, 21, 'FOOD'), (23, 34, 'FOOD'), (39, 56, 'FOOD')]}),
#   ('I tasted some sunchokes, gaucamole and strawberry at the office',
#    {'entities': [(14, 23, 'FOOD'), (25, 34, 'FOOD'), (39, 49, 'FOOD')]}),
#   ('I had a seven layer cake, a chopped walnuts and salsa tatemada at home',
#    {'entities': [(8, 24, 'FOOD'), (28, 43, 'FOOD'), (48, 62, 'FOOD')]}),
#   ('Last night, I ate an fresh atlantic salmon with berry medley and pierogi potato',
#    {'entities': [(21, 42, 'FOOD'), (48, 60, 'FOOD'), (65, 79, 'FOOD')]}),
#   ('I had a sacchetti, a real turkey jerky and smoked cheddar cheese at home',
#    {'entities': [(8, 17, 'FOOD'), (21, 38, 'FOOD'), (43, 64, 'FOOD')]}),
#   ('I took a noodles, hummos and natural sprinkles on the weekend',
#    {'entities': [(9, 16, 'FOOD'), (18, 24, 'FOOD'), (29, 46, 'FOOD')]}),
#   ('I took a pearl barley, dills and collagen peptides on the weekend',
#    {'entities': [(9, 21, 'FOOD'), (23, 28, 'FOOD'), (33, 50, 'FOOD')]}),
#   ('I tasted some brazil nuts flour, cut corn and steakhouse seasoning at the office',
#    {'entities': [(14, 31, 'FOOD'), (33, 41, 'FOOD'), (46, 66, 'FOOD')]}),
#   ("I've already had a bag of zucchini, minis and ground bison from the fridge",
#    {'entities': [(26, 34, 'FOOD'), (36, 41, 'FOOD'), (46, 58, 'FOOD')]}),
#   ("I've already had a bag of corned beef hash, black chia seed and grassfed whole milk from the fridge",
#    {'entities': [(26, 42, 'FOOD'), (44, 59, 'FOOD'), (64, 83, 'FOOD')]}),
#   ("I've already had a bag of jawbreakers, louisiana crunch cake and arugula from the fridge",
#    {'entities': [(26, 37, 'FOOD'), (39, 60, 'FOOD'), (65, 72, 'FOOD')]}),
#   ('I ate a maraschinos cherries with premium chicken pie and thins just now',
#    {'entities': [(8, 28, 'FOOD'), (34, 53, 'FOOD'), (58, 63, 'FOOD')]}),
#   ('I tasted some lime beans, chicharrones de harina and diced jalapeno peppers at the office',
#    {'entities': [(14, 24, 'FOOD'), (26, 48, 'FOOD'), (53, 75, 'FOOD')]}),
#   ('I tasted some caramel, pitaahh chips and red beans at the office',
#    {'entities': [(14, 21, 'FOOD'), (23, 36, 'FOOD'), (41, 50, 'FOOD')]}),
#   ('I had a traditional ricotta cheese, a melon mix spears and strawberryboli at home',
#    {'entities': [(8, 34, 'FOOD'), (38, 54, 'FOOD'), (59, 73, 'FOOD')]}),
#   ('I devoured a jasminerice, galletas maria cookies and olive oil',
#    {'entities': [(13, 24, 'FOOD'), (26, 48, 'FOOD'), (53, 62, 'FOOD')]}),
#   ('I tasted some bacon french onion, english walnut pieces and chicken jambalaya at the office',
#    {'entities': [(14, 32, 'FOOD'), (34, 55, 'FOOD'), (60, 77, 'FOOD')]}),
#   ('I had a cultivated blueberries, a shredded lettuce and egg product at home',
#    {'entities': [(8, 30, 'FOOD'), (34, 50, 'FOOD'), (55, 66, 'FOOD')]}),
#   ('I had a kosher dill spears, a ginger and natural sea salt at home',
#    {'entities': [(8, 26, 'FOOD'), (30, 36, 'FOOD'), (41, 57, 'FOOD')]}),
#   ('I took a pickled sliced beets, cantaloupe spears and demi baguettes bread on the weekend',
#    {'entities': [(9, 29, 'FOOD'), (31, 48, 'FOOD'), (53, 73, 'FOOD')]}),
#   ('I devoured a green apple lollipop, puffers and pepperballs',
#    {'entities': [(13, 33, 'FOOD'), (35, 42, 'FOOD'), (47, 58, 'FOOD')]}),
#   ("There's a basket of luncheon meat, bolillos and mini pretzels that I consumed",
#    {'entities': [(20, 33, 'FOOD'), (35, 43, 'FOOD'), (48, 61, 'FOOD')]}),
#   ('I had a pimento stuffed olives, a pure golden honey and caperberries at home',
#    {'entities': [(8, 30, 'FOOD'), (34, 51, 'FOOD'), (56, 68, 'FOOD')]}),
#   ('I ate a kaiser buns with organic mayonnaise and paella just now',
#    {'entities': [(8, 19, 'FOOD'), (25, 43, 'FOOD'), (48, 54, 'FOOD')]}),
#   ("I've already had a bag of sorullos, poultry seasoning and instant from the fridge",
#    {'entities': [(26, 34, 'FOOD'), (36, 53, 'FOOD'), (58, 65, 'FOOD')]}),
#   ('I took a vegetable oil, serrano and natto on the weekend',
#    {'entities': [(9, 22, 'FOOD'), (24, 31, 'FOOD'), (36, 41, 'FOOD')]}),
#   ('I had a cheesesticks, a baked pretzel rods and juicebiotics at home',
#    {'entities': [(8, 20, 'FOOD'), (24, 42, 'FOOD'), (47, 59, 'FOOD')]}),
#   ('I took a fresh mozzarella medallions, roasted seaweed and trufffles on the weekend',
#    {'entities': [(9, 36, 'FOOD'), (38, 53, 'FOOD'), (58, 67, 'FOOD')]}),
#   ('I ate a raisin muffins with organic fudge bars and churros just now',
#    {'entities': [(8, 22, 'FOOD'), (28, 46, 'FOOD'), (51, 58, 'FOOD')]}),
#   ('I tasted some starlight mints, zur and big game crackers at the office',
#    {'entities': [(14, 29, 'FOOD'), (31, 34, 'FOOD'), (39, 56, 'FOOD')]}),
#   ('I took a kefir, limoncello and heirloom shakshuka on the weekend',
#    {'entities': [(9, 14, 'FOOD'), (16, 26, 'FOOD'), (31, 49, 'FOOD')]}),
#   ('I tasted some decors, blanched sliced almonds and vegetable for spaghetti at the office',
#    {'entities': [(14, 20, 'FOOD'), (22, 45, 'FOOD'), (50, 73, 'FOOD')]})],
#  'two_foods': [('last night, a avocados was sent to me with menudito',
#    {'entities': [(14, 22, 'FOOD'), (43, 51, 'FOOD')]}),
#   ('I made a blondies and sherbet for lunch',
#    {'entities': [(9, 17, 'FOOD'), (22, 29, 'FOOD')]}),
#   ('last night, a gummy snowflurries was sent to me with organic aloe water',
#    {'entities': [(14, 32, 'FOOD'), (53, 71, 'FOOD')]}),
#   ('I ate a whole water chestnuts and a coconut chips for lunch',
#    {'entities': [(8, 29, 'FOOD'), (36, 49, 'FOOD')]}),
#   ('I ate a chipotle wisconsin cheese and a lite mayonnaise for lunch',
#    {'entities': [(8, 33, 'FOOD'), (40, 55, 'FOOD')]}),
#   ('I ate a coffee with erythritol in the morning',
#    {'entities': [(8, 14, 'FOOD'), (20, 30, 'FOOD')]}),
#   ('I ate relish sandwich spread and myzithra',
#    {'entities': [(6, 28, 'FOOD'), (33, 41, 'FOOD')]}),
#   ('I ate a instant polenta cornmeal with clover honey in the morning',
#    {'entities': [(8, 32, 'FOOD'), (38, 50, 'FOOD')]}),
#   ('I ate a peppered beef jerky and a gum balls candy for lunch',
#    {'entities': [(8, 27, 'FOOD'), (34, 49, 'FOOD')]}),
#   ('I ate a cookie and a herbal infusion tea for lunch',
#    {'entities': [(8, 14, 'FOOD'), (21, 40, 'FOOD')]}),
#   ('I ate a cluster and a desserts for lunch',
#    {'entities': [(8, 15, 'FOOD'), (22, 30, 'FOOD')]}),
#   ('I made a potato gnocchi and organic ground beef for lunch',
#    {'entities': [(9, 23, 'FOOD'), (28, 47, 'FOOD')]}),
#   ('I had a licorice and a recaito today',
#    {'entities': [(8, 16, 'FOOD'), (23, 30, 'FOOD')]}),
#   ('I had a sriracha popcorn and a gumbo vegetables today',
#    {'entities': [(8, 24, 'FOOD'), (31, 47, 'FOOD')]}),
#   ('I had a bowl of coconut oil with sfornatini and I wanted to go to the mall today',
#    {'entities': [(16, 27, 'FOOD'), (33, 43, 'FOOD')]}),
#   ('I ate a alkaline water and a chocolate for lunch',
#    {'entities': [(8, 22, 'FOOD'), (29, 38, 'FOOD')]}),
#   ('I made a whiskey and camembert for lunch',
#    {'entities': [(9, 16, 'FOOD'), (21, 30, 'FOOD')]}),
#   ('I made a pandebono and maltose for lunch',
#    {'entities': [(9, 18, 'FOOD'), (23, 30, 'FOOD')]}),
#   ('last night, a toasted muesli was sent to me with crescent rolls',
#    {'entities': [(14, 28, 'FOOD'), (49, 63, 'FOOD')]}),
#   ('I made a whole peeled tomatoes and dessert shells for lunch',
#    {'entities': [(9, 30, 'FOOD'), (35, 49, 'FOOD')]}),
#   ('I ate a green tea with chunky portabella mushrooms in the morning',
#    {'entities': [(8, 17, 'FOOD'), (23, 50, 'FOOD')]}),
#   ('today I ate a white bread and a cut white corn for lunch',
#    {'entities': [(14, 25, 'FOOD'), (32, 46, 'FOOD')]}),
#   ('I had a hard pretzels and a vegan noodle today',
#    {'entities': [(8, 21, 'FOOD'), (28, 40, 'FOOD')]}),
#   ('last night, a mickey sprinkles was sent to me with whole grain cereal',
#    {'entities': [(14, 30, 'FOOD'), (51, 69, 'FOOD')]}),
#   ('I had a bowl of yellowfin with mild smoked salsa and I wanted to go to the mall today',
#    {'entities': [(16, 25, 'FOOD'), (31, 48, 'FOOD')]}),
#   ('I ate a sharp pinconning and a kimchi for lunch',
#    {'entities': [(8, 24, 'FOOD'), (31, 37, 'FOOD')]}),
#   ('last night, a zingers was sent to me with pomegranate',
#    {'entities': [(14, 21, 'FOOD'), (42, 53, 'FOOD')]}),
#   ('I had a mazamorra and a chia today',
#    {'entities': [(8, 17, 'FOOD'), (24, 28, 'FOOD')]}),
#   ('I had a matchstick carrots and a munchy medley today',
#    {'entities': [(8, 26, 'FOOD'), (33, 46, 'FOOD')]}),
#   ('last night, a slushy was sent to me with banana orange yogurt',
#    {'entities': [(14, 20, 'FOOD'), (41, 61, 'FOOD')]}),
#   ('I made a pretzels and low fat oatmilk for lunch',
#    {'entities': [(9, 17, 'FOOD'), (22, 37, 'FOOD')]}),
#   ('I had a bowl of lemon with whole cranberries and I wanted to go to the mall today',
#    {'entities': [(16, 21, 'FOOD'), (27, 44, 'FOOD')]}),
#   ('I ate a hilopitaki and a sweetened dried cranberries for lunch',
#    {'entities': [(8, 18, 'FOOD'), (25, 52, 'FOOD')]}),
#   ('today I ate a sour pickle bitez and a salametti for lunch',
#    {'entities': [(14, 31, 'FOOD'), (38, 47, 'FOOD')]}),
#   ('last night, a american slices cheese was sent to me with diced pancetta',
#    {'entities': [(14, 36, 'FOOD'), (57, 71, 'FOOD')]}),
#   ('I had a fudge bars and a basil  today',
#    {'entities': [(8, 18, 'FOOD'), (25, 31, 'FOOD')]}),
#   ('today I ate a blue candy shred and a burrata for lunch',
#    {'entities': [(14, 30, 'FOOD'), (37, 44, 'FOOD')]}),
#   ('I made a masa real guava and crispy marshmallow squares for lunch',
#    {'entities': [(9, 24, 'FOOD'), (29, 55, 'FOOD')]}),
#   ('I ate a beans with egg in the morning',
#    {'entities': [(8, 13, 'FOOD'), (19, 22, 'FOOD')]}),
#   ('last night, a large raw shrimp was sent to me with jos',
#    {'entities': [(14, 30, 'FOOD'), (51, 54, 'FOOD')]}),
#   ('today I ate a bbq and a chia seeds for lunch',
#    {'entities': [(14, 17, 'FOOD'), (24, 34, 'FOOD')]}),
#   ('I ate a chupalicious with mediterranean baklava in the morning',
#    {'entities': [(8, 20, 'FOOD'), (26, 47, 'FOOD')]}),
#   ('I had a bowl of grahams with manicotti and I wanted to go to the mall today',
#    {'entities': [(16, 23, 'FOOD'), (29, 38, 'FOOD')]}),
#   ('I had a coconut dipped and a straws today',
#    {'entities': [(8, 22, 'FOOD'), (29, 35, 'FOOD')]}),
#   ('I ate a quesadillas and a buttermints for lunch',
#    {'entities': [(8, 19, 'FOOD'), (26, 37, 'FOOD')]}),
#   ('I made a sugar snap peas and brioche buns for lunch',
#    {'entities': [(9, 24, 'FOOD'), (29, 41, 'FOOD')]}),
#   ('last night, a mashed potatoes was sent to me with spreads',
#    {'entities': [(14, 29, 'FOOD'), (50, 57, 'FOOD')]}),
#   ('I ate a tuna with rolo in the morning',
#    {'entities': [(8, 12, 'FOOD'), (18, 22, 'FOOD')]}),
#   ('I had a congee and a garanola today',
#    {'entities': [(8, 14, 'FOOD'), (21, 29, 'FOOD')]}),
#   ('I had a bowl of raw almonds with saltines and I wanted to go to the mall today',
#    {'entities': [(16, 27, 'FOOD'), (33, 41, 'FOOD')]}),
#   ('today I ate a refried black beans and a agnolotti for lunch',
#    {'entities': [(14, 33, 'FOOD'), (40, 49, 'FOOD')]}),
#   ('I ate a provolone and a chick peas for lunch',
#    {'entities': [(8, 17, 'FOOD'), (24, 34, 'FOOD')]}),
#   ('I ate a mulberries with cocktail shrimp in the morning',
#    {'entities': [(8, 18, 'FOOD'), (24, 39, 'FOOD')]}),
#   ('last night, a sliced peeled apples was sent to me with cheeseburgerito',
#    {'entities': [(14, 34, 'FOOD'), (55, 70, 'FOOD')]}),
#   ('I made a tartar sauce and chocomaker for lunch',
#    {'entities': [(9, 21, 'FOOD'), (26, 36, 'FOOD')]}),
#   ('I had a bowl of sauce with holiday egg nog and I wanted to go to the mall today',
#    {'entities': [(16, 21, 'FOOD'), (27, 42, 'FOOD')]}),
#   ('I had a squeezable cheddar cheese and a uncured beef smokies today',
#    {'entities': [(8, 33, 'FOOD'), (40, 60, 'FOOD')]}),
#   ('I ate a sweet relish and a creole for lunch',
#    {'entities': [(8, 20, 'FOOD'), (27, 33, 'FOOD')]}),
#   ('last night, a oyster crackers was sent to me with candy watches',
#    {'entities': [(14, 29, 'FOOD'), (50, 63, 'FOOD')]}),
#   ('I ate a turkey sausage with baked snack crackers in the morning',
#    {'entities': [(8, 22, 'FOOD'), (28, 48, 'FOOD')]}),
#   ('I ate a fettuccine with fresh steam peas in the morning',
#    {'entities': [(8, 18, 'FOOD'), (24, 40, 'FOOD')]}),
#   ('I ate hearts of romaine and lingonberries',
#    {'entities': [(6, 23, 'FOOD'), (28, 41, 'FOOD')]}),
#   ('last night, a valley fresh butter was sent to me with sushi',
#    {'entities': [(14, 33, 'FOOD'), (54, 59, 'FOOD')]}),
#   ('I had a bowl of tradition bourgogne with squeeze whipped dressing and I wanted to go to the mall today',
#    {'entities': [(16, 35, 'FOOD'), (41, 65, 'FOOD')]}),
#   ('I ate a smoked jalapeno sausage and a maple turkey sandwich for lunch',
#    {'entities': [(8, 31, 'FOOD'), (38, 59, 'FOOD')]}),
#   ('last night, a cod was sent to me with peanut oil',
#    {'entities': [(14, 17, 'FOOD'), (38, 48, 'FOOD')]}),
#   ('I ate tilapia and spinach quiche',
#    {'entities': [(6, 13, 'FOOD'), (18, 32, 'FOOD')]}),
#   ('I ate a worcestershire sauce with mints in the morning',
#    {'entities': [(8, 28, 'FOOD'), (34, 39, 'FOOD')]}),
#   ('today I ate a prawn dumplings and a gruyere cheese for lunch',
#    {'entities': [(14, 29, 'FOOD'), (36, 50, 'FOOD')]}),
#   ('I had a creamsicle and a celery sticks today',
#    {'entities': [(8, 18, 'FOOD'), (25, 38, 'FOOD')]}),
#   ('I made a lite salt and spanakopita for lunch',
#    {'entities': [(9, 18, 'FOOD'), (23, 34, 'FOOD')]}),
#   ('I had a organic quinoa and a haupia today',
#    {'entities': [(8, 22, 'FOOD'), (29, 35, 'FOOD')]}),
#   ('last night, a chili  was sent to me with bean threads',
#    {'entities': [(14, 20, 'FOOD'), (41, 53, 'FOOD')]}),
#   ('today I ate a wholes and a crab meat for lunch',
#    {'entities': [(14, 20, 'FOOD'), (27, 36, 'FOOD')]}),
#   ('I ate sweet tea and chopped ripe olives',
#    {'entities': [(6, 15, 'FOOD'), (20, 39, 'FOOD')]}),
#   ('I had a gourmet carrots and a crispy garden salad today',
#    {'entities': [(8, 23, 'FOOD'), (30, 49, 'FOOD')]}),
#   ('I made a muesli and kolita for lunch',
#    {'entities': [(9, 15, 'FOOD'), (20, 26, 'FOOD')]}),
#   ('last night, a portobello mushroom sauce was sent to me with sweet kernel corn',
#    {'entities': [(14, 39, 'FOOD'), (60, 77, 'FOOD')]}),
#   ('today I ate a bison patties and a pizzelle for lunch',
#    {'entities': [(14, 27, 'FOOD'), (34, 42, 'FOOD')]}),
#   ('I ate a extra fancy paprika and a dippers graham snacks for lunch',
#    {'entities': [(8, 27, 'FOOD'), (34, 55, 'FOOD')]}),
#   ('last night, a soursop in syrup was sent to me with pasteurized egg whites',
#    {'entities': [(14, 30, 'FOOD'), (51, 73, 'FOOD')]}),
#   ('I ate biscuits  and mini marshmallows',
#    {'entities': [(6, 15, 'FOOD'), (20, 37, 'FOOD')]}),
#   ('I ate energizer trail mix and chicken',
#    {'entities': [(6, 25, 'FOOD'), (30, 37, 'FOOD')]}),
#   ('I ate a whole baby corn and a peanut caramel clusters for lunch',
#    {'entities': [(8, 23, 'FOOD'), (30, 53, 'FOOD')]}),
#   ('I had a bowl of pineapple juice with steak and I wanted to go to the mall today',
#    {'entities': [(16, 31, 'FOOD'), (37, 42, 'FOOD')]}),
#   ('I made a hoagies bread and blondie for lunch',
#    {'entities': [(9, 22, 'FOOD'), (27, 34, 'FOOD')]}),
#   ('today I ate a curry powder and a brownie bites for lunch',
#    {'entities': [(14, 26, 'FOOD'), (33, 46, 'FOOD')]}),
#   ('I had a tandoori masala and a catsup today',
#    {'entities': [(8, 23, 'FOOD'), (30, 36, 'FOOD')]}),
#   ('I ate a chicken wings with mortadella in the morning',
#    {'entities': [(8, 21, 'FOOD'), (27, 37, 'FOOD')]}),
#   ('last night, a giardeniera was sent to me with tempeh',
#    {'entities': [(14, 25, 'FOOD'), (46, 52, 'FOOD')]}),
#   ('I ate a chocolate chip cookies with mississippi mud cake in the morning',
#    {'entities': [(8, 30, 'FOOD'), (36, 56, 'FOOD')]}),
#   ('I ate a organic red beans and a refresh for lunch',
#    {'entities': [(8, 25, 'FOOD'), (32, 39, 'FOOD')]}),
#   ('today I ate a queso and a besan for lunch',
#    {'entities': [(14, 19, 'FOOD'), (26, 31, 'FOOD')]}),
#   ('today I ate a profiteroles and a shredded parmesan cheese for lunch',
#    {'entities': [(14, 26, 'FOOD'), (33, 57, 'FOOD')]}),
#   ('I had a bowl of gluten free spaghetti with baked peanut puffs and I wanted to go to the mall today',
#    {'entities': [(16, 37, 'FOOD'), (43, 61, 'FOOD')]}),
#   ('I made a alexander and fillets for lunch',
#    {'entities': [(9, 18, 'FOOD'), (23, 30, 'FOOD')]}),
#   ('I ate a daiquiri and a authentic refried beans for lunch',
#    {'entities': [(8, 16, 'FOOD'), (23, 46, 'FOOD')]}),
#   ('I ate traditional pizza dough and trout',
#    {'entities': [(6, 29, 'FOOD'), (34, 39, 'FOOD')]}),
#   ('I ate a acorn squash with rootbeer in the morning',
#    {'entities': [(8, 20, 'FOOD'), (26, 34, 'FOOD')]}),
#   ('I ate mani tostado salado and biscoff',
#    {'entities': [(6, 25, 'FOOD'), (30, 37, 'FOOD')]}),
#   ('I had a bowl of premium cookies with punch and I wanted to go to the mall today',
#    {'entities': [(16, 31, 'FOOD'), (37, 42, 'FOOD')]}),
#   ('I made a italian dressing and marshmallow treat magic for lunch',
#    {'entities': [(9, 25, 'FOOD'), (30, 53, 'FOOD')]}),
#   ('last night, a pecan halves was sent to me with rub style pizza',
#    {'entities': [(14, 26, 'FOOD'), (47, 62, 'FOOD')]}),
#   ('last night, a organic saltine crackers was sent to me with farmer cheese',
#    {'entities': [(14, 38, 'FOOD'), (59, 72, 'FOOD')]}),
#   ('last night, a razz was sent to me with sliced stewed tomatoes',
#    {'entities': [(14, 18, 'FOOD'), (39, 61, 'FOOD')]}),
#   ('last night, a decorating purple sugar was sent to me with baby cut carrots',
#    {'entities': [(14, 37, 'FOOD'), (58, 74, 'FOOD')]}),
#   ('I ate a boiled custard and a keta salmon fillets for lunch',
#    {'entities': [(8, 22, 'FOOD'), (29, 48, 'FOOD')]}),
#   ('today I ate a arrabbiata and a pie for lunch',
#    {'entities': [(14, 24, 'FOOD'), (31, 34, 'FOOD')]}),
#   ('today I ate a gingerale and a puree for lunch',
#    {'entities': [(14, 23, 'FOOD'), (30, 35, 'FOOD')]}),
#   ('last night, a meringue powder was sent to me with seasoned mushroom curry',
#    {'entities': [(14, 29, 'FOOD'), (50, 73, 'FOOD')]}),
#   ('I made a red popcorn and nibs for lunch',
#    {'entities': [(9, 20, 'FOOD'), (25, 29, 'FOOD')]}),
#   ('I ate a sliced peaches and a rotini for lunch',
#    {'entities': [(8, 22, 'FOOD'), (29, 35, 'FOOD')]}),
#   ('I made a buffalo chicken slider and spreadable cheddar cheese for lunch',
#    {'entities': [(9, 31, 'FOOD'), (36, 61, 'FOOD')]}),
#   ('I made a mixed heart pretzels and pies for lunch',
#    {'entities': [(9, 29, 'FOOD'), (34, 38, 'FOOD')]}),
#   ('today I ate a cocoa and a crisps for lunch',
#    {'entities': [(14, 19, 'FOOD'), (26, 32, 'FOOD')]}),
#   ('I ate lolliheart and medjool dates',
#    {'entities': [(6, 16, 'FOOD'), (21, 34, 'FOOD')]}),
#   ('I ate a steelhead trout portion with chocolat in the morning',
#    {'entities': [(8, 31, 'FOOD'), (37, 45, 'FOOD')]}),
#   ('last night, a coconola was sent to me with tea',
#    {'entities': [(14, 22, 'FOOD'), (43, 46, 'FOOD')]}),
#   ('I ate sparkling sugars and chocolate candies',
#    {'entities': [(6, 22, 'FOOD'), (27, 44, 'FOOD')]}),
#   ('I ate a katchup and a oat bran for lunch',
#    {'entities': [(8, 15, 'FOOD'), (22, 30, 'FOOD')]}),
#   ('last night, a white nougat almonds was sent to me with plantain chips',
#    {'entities': [(14, 34, 'FOOD'), (55, 69, 'FOOD')]}),
#   ('I had a creamy onion rings and a chocolate syrup today',
#    {'entities': [(8, 26, 'FOOD'), (33, 48, 'FOOD')]}),
#   ('I ate a idaho potatoes and a cookedsquash for lunch',
#    {'entities': [(8, 22, 'FOOD'), (29, 41, 'FOOD')]}),
#   ('I ate a salad meal with biscotti in the morning',
#    {'entities': [(8, 18, 'FOOD'), (24, 32, 'FOOD')]}),
#   ('I ate a snakaroons and a anchovies for lunch',
#    {'entities': [(8, 18, 'FOOD'), (25, 34, 'FOOD')]}),
#   ('I ate a extra thick bologna with cinnamon graham crackers in the morning',
#    {'entities': [(8, 27, 'FOOD'), (33, 57, 'FOOD')]}),
#   ('I ate a sea salt grinder and a vegetable chips for lunch',
#    {'entities': [(8, 24, 'FOOD'), (31, 46, 'FOOD')]}),
#   ('last night, a tropical was sent to me with whipped dressing',
#    {'entities': [(14, 22, 'FOOD'), (43, 59, 'FOOD')]}),
#   ('I ate waffles and veggie sausage links',
#    {'entities': [(6, 13, 'FOOD'), (18, 38, 'FOOD')]}),
#   ('last night, a whipped peanut spread was sent to me with salsa',
#    {'entities': [(14, 35, 'FOOD'), (56, 61, 'FOOD')]}),
#   ('I ate a hermits with jam in the morning',
#    {'entities': [(8, 15, 'FOOD'), (21, 24, 'FOOD')]}),
#   ('I ate a korean chili sauce with wedding buttermints in the morning',
#    {'entities': [(8, 26, 'FOOD'), (32, 51, 'FOOD')]}),
#   ('I made a holiday cookie tray and pineapple spears for lunch',
#    {'entities': [(9, 28, 'FOOD'), (33, 49, 'FOOD')]}),
#   ('today I ate a ceviche and a diced onions for lunch',
#    {'entities': [(14, 21, 'FOOD'), (28, 40, 'FOOD')]}),
#   ('I ate a cold pressed lemonade and a organic pinto beans for lunch',
#    {'entities': [(8, 29, 'FOOD'), (36, 55, 'FOOD')]}),
#   ('last night, a natilla was sent to me with whole dill pickles',
#    {'entities': [(14, 21, 'FOOD'), (42, 60, 'FOOD')]}),
#   ('I had a bowl of sub sandwich rolls with sencha green tea and I wanted to go to the mall today',
#    {'entities': [(16, 34, 'FOOD'), (40, 56, 'FOOD')]}),
#   ('I made a cereal and mozzarella for lunch',
#    {'entities': [(9, 15, 'FOOD'), (20, 30, 'FOOD')]}),
#   ('last night, a sweetie was sent to me with figs',
#    {'entities': [(14, 21, 'FOOD'), (42, 46, 'FOOD')]}),
#   ('today I ate a chicken strips and a fruit punch for lunch',
#    {'entities': [(14, 28, 'FOOD'), (35, 46, 'FOOD')]}),
#   ('today I ate a calamari and a preserve for lunch',
#    {'entities': [(14, 22, 'FOOD'), (29, 37, 'FOOD')]}),
#   ('I ate a chopped broccoli with root beer in the morning',
#    {'entities': [(8, 24, 'FOOD'), (30, 39, 'FOOD')]}),
#   ('I had a fioretti and a italian susage tortelloni today',
#    {'entities': [(8, 16, 'FOOD'), (23, 48, 'FOOD')]}),
#   ('I ate enriched dinner rolls and shrimp dumplings',
#    {'entities': [(6, 27, 'FOOD'), (32, 48, 'FOOD')]}),
#   ('last night, a feta was sent to me with atlantic salmon portion',
#    {'entities': [(14, 18, 'FOOD'), (39, 62, 'FOOD')]}),
#   ('last night, a dumplings was sent to me with premium ground beef',
#    {'entities': [(14, 23, 'FOOD'), (44, 63, 'FOOD')]}),
#   ('today I ate a crunch dunkers and a harvest cheesecake for lunch',
#    {'entities': [(14, 28, 'FOOD'), (35, 53, 'FOOD')]}),
#   ('I ate a white chicken chili with mirepoix diced in the morning',
#    {'entities': [(8, 27, 'FOOD'), (33, 47, 'FOOD')]}),
#   ('I had a bowl of swanson broth chicken with chopped onions and I wanted to go to the mall today',
#    {'entities': [(16, 37, 'FOOD'), (43, 57, 'FOOD')]}),
#   ('I had a russet idaho potatoes and a onion today',
#    {'entities': [(8, 29, 'FOOD'), (36, 41, 'FOOD')]}),
#   ('I ate a organic canola oil and a pappardelle for lunch',
#    {'entities': [(8, 26, 'FOOD'), (33, 44, 'FOOD')]}),
#   ('I ate a superfood seedbar with waffle chips in the morning',
#    {'entities': [(8, 25, 'FOOD'), (31, 43, 'FOOD')]}),
#   ('I made a cheesy bacon burgers and ground beef for lunch',
#    {'entities': [(9, 29, 'FOOD'), (34, 45, 'FOOD')]}),
#   ('I ate a cupcakes and a chunky for lunch',
#    {'entities': [(8, 16, 'FOOD'), (23, 29, 'FOOD')]}),
#   ('I ate a low fat waffles and a all vegetable shortening for lunch',
#    {'entities': [(8, 23, 'FOOD'), (30, 54, 'FOOD')]}),
#   ('today I ate a corn oil and a palmeritas for lunch',
#    {'entities': [(14, 22, 'FOOD'), (29, 39, 'FOOD')]}),
#   ('I ate a chelada with sliced sandwich rolls in the morning',
#    {'entities': [(8, 15, 'FOOD'), (21, 42, 'FOOD')]}),
#   ('last night, a flaxseed was sent to me with popsicle',
#    {'entities': [(14, 22, 'FOOD'), (43, 51, 'FOOD')]}),
#   ('I had a bowl of whole mushrooms with crunchy wheatberry and I wanted to go to the mall today',
#    {'entities': [(16, 31, 'FOOD'), (37, 55, 'FOOD')]}),
#   ('I ate a pasta and a pizza cookie for lunch',
#    {'entities': [(8, 13, 'FOOD'), (20, 32, 'FOOD')]}),
#   ('I had a bowl of diet cola with gummy watermelon rings and I wanted to go to the mall today',
#    {'entities': [(16, 25, 'FOOD'), (31, 53, 'FOOD')]}),
#   ('today I ate a andouille and a roasted root vegetables for lunch',
#    {'entities': [(14, 23, 'FOOD'), (30, 53, 'FOOD')]}),
#   ('I ate a veggie dogs with marinara in the morning',
#    {'entities': [(8, 19, 'FOOD'), (25, 33, 'FOOD')]}),
#   ('today I ate a premium blueberries and a tastykrisps for lunch',
#    {'entities': [(14, 33, 'FOOD'), (40, 51, 'FOOD')]}),
#   ('I ate chevre and caviar',
#    {'entities': [(6, 12, 'FOOD'), (17, 23, 'FOOD')]}),
#   ('I had a mini wafers and a creamy coconut today',
#    {'entities': [(8, 19, 'FOOD'), (26, 40, 'FOOD')]}),
#   ('last night, a cannellini alubias was sent to me with broccoli',
#    {'entities': [(14, 32, 'FOOD'), (53, 61, 'FOOD')]})]}

# %%
import json
    
with open("TRAIN_FOOD_DATA(1).json", "w") as outfile:
    json.dump(TRAIN_FOOD_DATA, outfile)

# %%
import json
    
with open("TEST_FOOD_DATA(1).json", "w") as outfile:
    json.dump(TEST_FOOD_DATA, outfile)
